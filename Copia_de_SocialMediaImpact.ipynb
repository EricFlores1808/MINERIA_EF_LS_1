# %% [markdown]
# <a href="https://colab.research.google.com/github/EricFlores1808/MINERIA_EF_LS_1/blob/eric_desarrollo/Copia_de_SocialMediaImpact.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("/content/Teen_Mental_Health_Dataset.csv")

# %%
df.head()
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...

# %%
print("--------------- Informacion del Dataset ---------------")
df.info()

#Buscamos ver todas las columnas que existen, ademas de el tipo de dato que son.
# Out:
# --------------- Informacion del Dataset ---------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1200 non-null   int64
#  1   gender                    1200 non-null   object
#  2   daily_social_media_hours  1200 non-null   float64
#  3   platform_usage            1200 non-null   object
#  4   sleep_hours               1200 non-null   float64
#  5   screen_time_before_sleep  1200 non-null   float64
#  6   academic_performance      1200 non-null   float64
#  7   physical_activity         1200 non-null   float64
#  8   social_interaction_level  1200 non-null   object
#  9   stress_level              1200 non-null   int64
#  10  anxiety_level             1200 non-null   int64
#  11  addiction_level           1200 non-null   int64
# ...

# %%
print("------ Conteo de nulos ------")
print(df.isna().sum())
print("-----------------------------")
print(f"Registros duplicados encontrados: {df.duplicated().sum()}")

#Aca buscamos ver cuantos nulos existen en cada columna ademas de encontrar datos duplicados si es que existieran.
# Out:
# ------ Conteo de nulos ------
# age                         0
# gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# anxiety_level               0
# addiction_level             0
# depression_label            0
# dtype: int64
# -----------------------------
# Registros duplicados encontrados: 0

# %%
cant_cat_plat = df['platform_usage'].value_counts()
print(cant_cat_plat)
print("-----------------------------")
cant_cat_si = df['social_interaction_level'].value_counts()
print(cant_cat_si)
print("-----------------------------")
cant_cat_gen = df['gender'].value_counts()
print(cant_cat_gen)

#Aca podemos ver todas las categorias que existen dentro de las nominales y ordinarias
# Out:
# platform_usage
# Instagram    411
# TikTok       398
# Both         391
# Name: count, dtype: int64
# -----------------------------
# social_interaction_level
# medium    416
# low       415
# high      369
# Name: count, dtype: int64
# -----------------------------
# gender
# male      615
# female    585
# Name: count, dtype: int64

# %% [markdown]
# #Acá podemos ver que el promedio de horas que los adolecentes pasan en redes sociales son de 5 horas

# %%
# @title Promedio de horas de los adolecentes en las RRSS y sus relaciones de salud mental, y rendimiento acádemico.
df.describe().round()
# Out:
#           age  daily_social_media_hours  sleep_hours  \
# count  1200.0                    1200.0       1200.0
# mean     16.0                       5.0          6.0
# std       2.0                       2.0          1.0
# min      13.0                       1.0          4.0
# 25%      14.0                       3.0          5.0
# 50%      16.0                       4.0          6.0
# 75%      18.0                       6.0          8.0
# max      19.0                       8.0          9.0
#
#        screen_time_before_sleep  academic_performance  physical_activity  \
# count                    1200.0                1200.0             1200.0
# mean                        2.0                   3.0                1.0
# std                         1.0                   1.0                1.0
# min                         0.0                   2.0                0.0
# 25%                         1.0                   2.0                0.0
# ...

# %% [markdown]
# #Aca podemos ver como es el rango de edad de los participantes
# #ademas de ver la cantidad que tenemos en cada uno

# %%
# @title Distribución de edad de los participantes
sb.histplot(df['age'], kde=True, color='skyblue')
plt.title('Distribución de Edad de los Participantes')
plt.show()

# %% [markdown]
# #Acá podemos ver la distribución de género entre másculino y femenino, en lo cuál se puede observar que en su mayoría son hombres.

# %%
sb.countplot(data=df, x='gender', palette='pastel')
plt.title('Distribución por Género')
plt.show()
# Out:
# /tmp/ipykernel_16140/851705335.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=df, x='gender', palette='pastel')

# %% [markdown]
# #áca podemos observar un gráfico de barras en el cuál se interpreta el uso de las diferentes plataformas, en el cuál están incluidas : Tik Tok, Instagram,
# #y el uso de ambas plataformas por los diferentes usuarios analizados, dando a resaltar un escalonado, en el cuál va más bajo el uso de ambas plataformas, subiendo por "Tik Tok", y liderando la tabla con "Instagram".

# %%
sb.countplot(data=df, x='platform_usage', palette='viridis')
plt.title('Uso de plataformas')
plt.show()
# Out:
# /tmp/ipykernel_16140/3927043910.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=df, x='platform_usage', palette='viridis')

# %% [markdown]
# #En estos gráficos se ven la representación, de los 3 gráficos anteriormente mostrados, donde se ve la representación de la distribución de genero, el uso de plataformas, y la distribución de edad de los participantes.

# %%
# Configuración visual
sb.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# Distribución de Género y Plataforma
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

sb.countplot(data=df, x='gender', palette='pastel', ax=ax[0])
ax[0].set_title('Distribución por Género')

sb.countplot(data=df, x='platform_usage', palette='viridis', ax=ax[1])
ax[1].set_title('Uso de Plataformas')

sb.histplot(df['age'], kde=True, color='skyblue', palette='pastel', ax=ax[2])
ax[2].set_title('Distribución de Edad de los Participantes')

plt.tight_layout(pad=3.0)
plt.show()
# Out:
# /tmp/ipykernel_16140/3438892084.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=df, x='gender', palette='pastel', ax=ax[0])
# /tmp/ipykernel_16140/3438892084.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(data=df, x='platform_usage', palette='viridis', ax=ax[1])
# /tmp/ipykernel_16140/3438892084.py:14: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sb.histplot(df['age'], kde=True, color='skyblue', palette='pastel', ax=ax[2])

# %% [markdown]
# #En este digrama de cajas podemos ver la representación, de la distribución de los indicadores de salud mental.
# #En el cuál los 3 tienen distribuciónes similares, entre el estrés, la ansiedad y la adicción donde se nota que esta entre 3 y 8 y la mediana se encuentra entre el 5 y 6

# %%
# Visualización de indicadores de salud mental
plt.figure(figsize=(12, 6))
health_vars = ['stress_level', 'anxiety_level', 'addiction_level']
sb.boxplot(data=df[health_vars], palette="Pastel1")
plt.title('Distribución de Indicadores de Salud Mental')
plt.ylabel('Escala (1-10)')
plt.show()

# %% [markdown]
# #Áca podemos ver la relación entre las horas de uso y el rendimiento académico de los alumnos, mediante in gráfico de dispersión.

# %%
# Relación entre horas de uso y notas
plt.figure(figsize=(10, 6))
sb.regplot(data=df, x='daily_social_media_hours', y='academic_performance',
           scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Impacto del Uso de RRSS en el Rendimiento Académico')
plt.xlabel('Horas Diarias en Redes Sociales')
plt.ylabel('Calificación (GPA)')
plt.show()

# %% [markdown]
# #En este gráfico de barras, se da a conocer la interpretación de la interación social de los adolecentes vs su nivel de estrés. con una categorización de bajo, medio y alto.

# %%
# Gráfico de barras comparativo: Interacción Social vs Estrés
plt.figure(figsize=(10, 6))
sb.barplot(data=df, x='social_interaction_level', y='stress_level',
           order=['low', 'medium', 'high'], palette="viridis")
plt.title('Nivel de Estrés según Interacción Social Real')
plt.show()
# Out:
# /tmp/ipykernel_16140/1429320481.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(data=df, x='social_interaction_level', y='stress_level',

# %%
# Eliminar columnas no deseadas
cols_to_remove = [col for col in df_encoded.columns
                  if 'platform_usage' in col
                  or 'gender' in col
                  or col in ['age', 'screen_time_before_sleep']]

df_filtered = df_encoded.drop(columns=cols_to_remove)

# Heatmap sin esas variables
plt.figure(figsize=(14, 10))
sb.heatmap(df_filtered.corr(), annot=True, cmap='RdYlGn', fmt=".2f")
plt.title('Matriz de Correlación (Filtrada)')
plt.show()


# Proceso de Encoding para variables categóricas
df_encoded = df.copy()

# 1. Label Encoding para niveles (Ordinal)
map_social = {'low': 0, 'medium': 1, 'high': 2}
df_encoded['social_interaction_level'] = df_encoded['social_interaction_level'].map(map_social)

# 2. Get Dummies (One-Hot Encoding) para Plataforma y Género (Nominal)
# Esto crea columnas como 'platform_usage_TikTok', 'gender_female', etc.
df_encoded = pd.get_dummies(df_encoded, columns=['platform_usage', 'gender'], drop_first=True)

# Ahora la matriz de correlación incluirá TODO
plt.figure(figsize=(14, 10))
sb.heatmap(df_encoded.corr(), annot=True, cmap='RdYlGn', fmt=".2f")
plt.title('Matriz de Correlación con Variables Encodeadas')
plt.show()

# %%
cols_to_remove = [col for col in df_encoded.columns
                  if 'platform_usage' in col
                  or 'gender' in col
                  or col in ['age', 'screen_time_before_sleep', 'daily_social_media_hours']]

df_filtered = df_encoded.drop(columns=cols_to_remove)

# Heatmap sin esas variables
plt.figure(figsize=(14, 10))
sb.heatmap(df_filtered.corr(), annot=True, cmap='RdYlGn', fmt=".2f")
plt.title('Matriz de Correlación (Filtrada)')
plt.show()

# %%
cols_focus = [
    'social_interaction_level',
    'daily_social_media_hours',
    'addiction_level',
    'stress_level',
    'anxiety_level',
    'sleep_hours'
]

df_focus = df_encoded[cols_focus]

plt.figure(figsize=(10, 6))
sb.heatmap(df_focus.corr(), annot=True, cmap='RdYlGn', fmt=".2f")
plt.title('Relación: Interacción Social vs Uso de Redes')
plt.show()

# %% [markdown]
# #En este gráfico de torta, se da a conocer la interpretación de la interación social de los adolecentes en un formato de distribución porcentual, en el cuál se interpretan en "baja", "media", "alta", donde pre domina la categoría "media" con un 35.2%.

# %%
labels_map = {0: 'Baja', 1: 'Media', 2: 'Alta'}
niveles_labels = [labels_map[n] for n in niveles]

plt.figure(figsize=(8,8))
plt.pie(porcentajes, labels=niveles_labels, autopct='%1.1f%%')
plt.title('Distribución porcentual de horas de uso según interacción social')
plt.show()
